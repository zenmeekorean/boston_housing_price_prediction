# %% [markdown]
# Predicting Boston housing prices using regression models (CMEDV: a numeric vector of corrected median values of owner-occupied housing in USD 1000)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
boston_df = pd.read_csv('Sparta_CodingClub_Boston.csv')

# %%
boston_df
# Out:
#            TOWN  TOWN#      LON      LAT  CMEDV     CRIM    ZN  INDUS  CHAS  \
# 0        Nahant      0 -70.9550  42.2550   24.0  0.00632  18.0   2.31     0
# 1    Swampscott      1 -70.9500  42.2875   21.6  0.02731   0.0   7.07     0
# 2    Swampscott      1 -70.9360  42.2830   34.7  0.02729   0.0   7.07     0
# 3    Marblehead      2 -70.9280  42.2930   33.4  0.03237   0.0   2.18     0
# 4    Marblehead      2 -70.9220  42.2980   36.2  0.06905   0.0   2.18     0
# ..          ...    ...      ...      ...    ...      ...   ...    ...   ...
# 501    Winthrop     91 -70.9860  42.2312   22.4  0.06263   0.0  11.93     0
# 502    Winthrop     91 -70.9910  42.2275   20.6  0.04527   0.0  11.93     0
# 503    Winthrop     91 -70.9948  42.2260   23.9  0.06076   0.0  11.93     0
# 504    Winthrop     91 -70.9875  42.2240   22.0  0.10959   0.0  11.93     0
# 505    Winthrop     91 -70.9825  42.2210   19.0  0.04741   0.0  11.93     0
#
# ...

# %% [markdown]
# Meaning of acronym could be found here: https://www.rdocumentation.org/packages/spdep/versions/0.6-15/topics/boston

# %%
boston_df.isnull().sum()
# Out:
# TOWN       0
# TOWN#      0
# LON        0
# LAT        0
# CMEDV      0
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
del boston_df['TOWN#'] 
#as name of the town already exists

# %%
boston_df
# Out:
#            TOWN      LON      LAT  CMEDV     CRIM    ZN  INDUS  CHAS    NOX  \
# 0        Nahant -70.9550  42.2550   24.0  0.00632  18.0   2.31     0  0.538
# 1    Swampscott -70.9500  42.2875   21.6  0.02731   0.0   7.07     0  0.469
# 2    Swampscott -70.9360  42.2830   34.7  0.02729   0.0   7.07     0  0.469
# 3    Marblehead -70.9280  42.2930   33.4  0.03237   0.0   2.18     0  0.458
# 4    Marblehead -70.9220  42.2980   36.2  0.06905   0.0   2.18     0  0.458
# ..          ...      ...      ...    ...      ...   ...    ...   ...    ...
# 501    Winthrop -70.9860  42.2312   22.4  0.06263   0.0  11.93     0  0.573
# 502    Winthrop -70.9910  42.2275   20.6  0.04527   0.0  11.93     0  0.573
# 503    Winthrop -70.9948  42.2260   23.9  0.06076   0.0  11.93     0  0.573
# 504    Winthrop -70.9875  42.2240   22.0  0.10959   0.0  11.93     0  0.573
# 505    Winthrop -70.9825  42.2210   19.0  0.04741   0.0  11.93     0  0.573
#
# ...

# %% [markdown]
# Finding correlations between columns

# %%
columns = ['CMEDV', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

corr = boston_df[columns].corr(method = 'pearson')
corr
# Out:
#             CMEDV      CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CMEDV    1.000000 -0.389582  0.360386 -0.484754  0.175663 -0.429300  0.696304
# CRIM    -0.389582  1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN       0.360386 -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS   -0.484754  0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS     0.175663 -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX     -0.429300  0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM       0.696304 -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE     -0.377999  0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS      0.249315 -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD     -0.384766  0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX     -0.471979  0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# ...

# %%
#Make a heatmap
fig = plt.figure(figsize = (14, 10))
ax = fig.gca()

sns.set(font_scale=1.5)
hm = sns.heatmap(corr.values,
            cbar=True,
            annot=True, 
            square=True,
            fmt='.2f',
            annot_kws={'size': 15},
            yticklabels=columns,
            xticklabels=columns,
            ax=ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# From the heatmap, it can be seen that CMEDV is strongly correlated with RM,which refers to average numbers of rooms per dwelling (0.7) and LSTAT, the percentage values of lower status population (-0.74).
# Note that a correlation coefficient close to -1 indicates a strong negative correlation, not a low correlation.

# %%
from sklearn.preprocessing import StandardScaler #data normalization

scaler = StandardScaler() 
boston_df[columns] = scaler.fit_transform(boston_df[columns])

# %%
boston_df
# Out:
#            TOWN      LON      LAT     CMEDV      CRIM        ZN     INDUS  \
# 0        Nahant -70.9550  42.2550  0.160376 -0.419782  0.284830 -1.287909
# 1    Swampscott -70.9500  42.2875 -0.101258 -0.417339 -0.487722 -0.593381
# 2    Swampscott -70.9360  42.2830  1.326830 -0.417342 -0.487722 -0.593381
# 3    Marblehead -70.9280  42.2930  1.185112 -0.416750 -0.487722 -1.306878
# 4    Marblehead -70.9220  42.2980  1.490352 -0.412482 -0.487722 -1.306878
# ..          ...      ...      ...       ...       ...       ...       ...
# 501    Winthrop -70.9860  42.2312 -0.014047 -0.413229 -0.487722  0.115738
# 502    Winthrop -70.9910  42.2275 -0.210273 -0.415249 -0.487722  0.115738
# 503    Winthrop -70.9948  42.2260  0.149475 -0.413447 -0.487722  0.115738
# 504    Winthrop -70.9875  42.2240 -0.057653 -0.407764 -0.487722  0.115738
# 505    Winthrop -70.9825  42.2210 -0.384696 -0.415000 -0.487722  0.115738
#
#          CHAS       NOX        RM       AGE       DIS       RAD       TAX  \
# ...

# %%
from sklearn.model_selection import train_test_split

X = boston_df[columns]
y = boston_df['CMEDV']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=777)

# %%
#linear regression
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)

print(lr.score(X_test, y_test))
print(lr.score(X_train, y_train))
# Out:
# 1.0
# 1.0

# %%
print(lr.coef_)
# Out:
# [ 1.00000000e+00  8.34678732e-16 -9.82253522e-16  1.07862776e-15
#  -3.21457840e-16  1.06712462e-15 -1.07592570e-15  8.09473012e-16
#  -8.34794798e-16  1.08997009e-15  1.00339914e-15  8.51147324e-16
#  -5.62554951e-16  1.26510545e-15]

# %%
coefs = pd.DataFrame(zip(boston_df[columns].columns, lr.coef_), columns = ['feature', 'coefficients'])
coefs
# Out:
#     feature  coefficients
# 0     CMEDV  1.000000e+00
# 1      CRIM  8.346787e-16
# 2        ZN -9.822535e-16
# 3     INDUS  1.078628e-15
# 4      CHAS -3.214578e-16
# 5       NOX  1.067125e-15
# 6        RM -1.075926e-15
# 7       AGE  8.094730e-16
# 8       DIS -8.347948e-16
# 9       RAD  1.089970e-15
# 10      TAX  1.003399e-15
# 11  PTRATIO  8.511473e-16
# 12        B -5.625550e-16
# 13    LSTAT  1.265105e-15

# %% [markdown]
# The model to predict Boston housing price could be summurized as below: <br>
# 𝑦=22.5460−0.9112 CRIM+1.1255 ZN+0.1906 INDUS−2.1860 NOX+2.4701 RM+0.0345 AGE−3.4834 DIS+2.2827 RAD−2.3896 TAX−2.0444 PTRATIO+0.7542 B−4.1742 LSTAT
